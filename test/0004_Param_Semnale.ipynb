# %% [markdown]
# https://www.markdownguide.org/cheat-sheet/

# %% [markdown]
# # Testarea Automată a Circuitelor
#         --- Îndrumar de Laborator ---

# %% [markdown]
# ### Lucrarea nr. 4 - Masurarea parametrilor semnalelor

# %% [markdown]
# #### 4.3.1 Montajul experimental:
# ![fgen_osc_param_semnale.PNG](attachment:fgen_osc_param_semnale.PNG)

# %% [markdown]
# #### 4.3.2 Procedura de masurare:
# Folosind o buclă de tip „for” se vor genera mai multe semnale cu diferiți parametri.

# %% [markdown]
# #### 4.4 Codul sursa:
# 4.4.1 Initializarea instrumentelor si a interfetelor grafice

# %%
#using TIVM; # libraria responsabila de comunicatia cu instrumentele si cu interfetele grafice(front panels)
#using Plots; # libraria responsabila de generarea de grafice
#using DataFrames; #
#using CSV; # libraria responsabila de salvarea datelor in format .csv

# %%
# dmm_handle = connect!("ASRL1::INSTR")
# psu_handle = connect!("ASRL4::INSTR")
fgen_handle = connect!("ASRL5::INSTR")
scope_handle = connect!("USB0::0x0699::0x0364::C057729::INSTR")

# dmm = TIVM.GDM8246(dmm_handle);
# psu = TIVM.PST3201(psu_handle);
fgen = TIVM.GFG3015(fgen_handle);
scope = TIVM.TDS2002B(scope_handle);

# %%
# Panouri frontale pentru instrumente
#@async start_gui(psu_handle = psu_handle, dmm_handle = dmm_handle, fgen_handle = fgen_handle, scope_handle = scope_handle)
@async start_gui(fgen_handle = fgen_handle, scope_handle = scope_handle);

# %% [markdown]
# 4.4.2 Configurarea instrumentelor

# %%
# Generatorul de semnal
set_wfm(fgen, "C1", "sinusoid")
sleep(1)
set_freq(fgen, "C1", 1000)
sleep(1)
set_amplit_unit(fgen, "C1", "Vpp")
sleep(1)
set_amplit(fgen, "C1", 1)
sleep(1)
set_offs(fgen, "C1", 0)
sleep(1)
set_duty(fgen, "C1", 50)
sleep(1)

# %%
# Osciloscopul
#autoset is hidden :P
#ch coupling - WIP
set_ch_position(scope, "CH1", 0)
set_ch_position(scope, "CH2", 0)
#ch probe - do we need this?
set_vertical_scale(scope, "CH1", 1)
set_vertical_scale(scope, "CH2", 1)
set_horizontal_scale(scope, 0.001)
set_trig_ch(scope, "CH1")
set_trig_mode(scope, "NORMAL") # "NORMAL"/"AUTO"
set_trig_level(scope, 0.005)
# do we need trigger coupling or slope?
# Masuratori - se pot configura maxim 5 pt ambele canale impreuna
set_meas(scope, "MEAS1", "CH1", "FREQuency")
set_meas(scope, "MEAS2", "CH1", "PK2pk")
set_meas(scope, "MEAS3", "CH2", "FREQuency")
set_meas(scope, "MEAS4", "CH2", "PK2pk")
set_meas(scope, "MEAS5", "CH1", "PERIod")

# %% [markdown]
# 4.4.3 Definirea stimulilor si a variabilelor auxiliare

# %%
freq = 1e3:1e3:4e3
amplit = 0.5:0.5:3
in_freq = []
in_amplit = []
meas_freq = []
meas_amplit = []
crt_meas_amplit = 0
crt_meas_freq = 0
# Out:
# 0

# %% [markdown]
# 4.4.4 Bucla de masurare

# %%
in_freq = []
in_amplit = []
meas_freq = []
meas_amplit = []
for crt_freq in freq
    set_freq(fgen, "C1", crt_freq)
    tbase = 1/crt_freq
    set_horizontal_scale(scope, tbase)
    sleep(1)
    for crt_amplit in amplit        
        set_vertical_scale(scope, "CH1", crt_amplit/2)
        set_amplit(fgen, "C1", crt_amplit)                        
        sleep(2) # fgen and osc are slow to respond
        
        crt_meas_amplit = get_meas_data(scope, "MEAS2")
        crt_meas_freq = get_meas_data(scope, "MEAS1")

        # store crt stimuli value
        push!(in_freq, crt_freq)
        push!(in_amplit, crt_amplit)
        
        # store crt measurement value
        push!(meas_freq, crt_meas_freq)
        push!(meas_amplit, crt_meas_amplit)
        
        # print info to console
        @info "set_freq=$crt_freq, meas_freq=$crt_meas_freq, set_ampl=$crt_amplit, meas_ampl=$crt_meas_amplit"
    end
end
# Out:
# ┌ Info: set_freq=1000.0, meas_freq=992.0634765625, set_ampl=0.5, meas_ampl=1.0299999714
# └ @ Main In[6]:27
# ┌ Info: set_freq=1000.0, meas_freq=996.0159912109, set_ampl=1.0, meas_ampl=2.0799999237
# └ @ Main In[6]:27
# ┌ Info: set_freq=1000.0, meas_freq=996.0159912109, set_ampl=1.5, meas_ampl=3.1499998569
# └ @ Main In[6]:27
# ┌ Info: set_freq=1000.0, meas_freq=999.9999389648, set_ampl=2.0, meas_ampl=4.1199998856
# └ @ Main In[6]:27
# ┌ Info: set_freq=1000.0, meas_freq=996.677734375, set_ampl=2.5, meas_ampl=5.2500004768
# └ @ Main In[6]:27
# ┌ Info: set_freq=1000.0, meas_freq=1002.0039672852, set_ampl=3.0, meas_ampl=6.1799998283
# └ @ Main In[6]:27
# ┌ Info: set_freq=2000.0, meas_freq=2020.2020263672, set_ampl=0.5, meas_ampl=1.0299999714
# └ @ Main In[6]:27
# ┌ Info: set_freq=2000.0, meas_freq=2012.0723876953, set_ampl=1.0, meas_ampl=2.0399999619
# └ @ Main In[6]:27
# ┌ Info: set_freq=2000.0, meas_freq=1996.0080566406, set_ampl=1.5, meas_ampl=3.0899999142
# └ @ Main In[6]:27
# ┌ Info: set_freq=2000.0, meas_freq=1996.0080566406, set_ampl=2.0, meas_ampl=4.0799999237
# └ @ Main In[6]:27
# ┌ Info: set_freq=2000.0, meas_freq=1999.9998779297, set_ampl=2.5, meas_ampl=5.2000002861
# └ @ Main In[6]:27
# ┌ Info: set_freq=2000.0, meas_freq=1999.9998779297, set_ampl=3.0, meas_ampl=6.0599999428
# └ @ Main In[6]:27
# ┌ Info: set_freq=3000.0, meas_freq=3000.0, set_ampl=0.5, meas_ampl=1.0399999619
# └ @ Main In[6]:27
# ┌ Info: set_freq=3000.0, meas_freq=3012.0483398438, set_ampl=1.0, meas_ampl=2.0399999619
# └ @ Main In[6]:27
# ┌ Info: set_freq=3000.0, meas_freq=2994.0119628906, set_ampl=1.5, meas_ampl=3.0599999428
# └ @ Main In[6]:27
# ┌ Info: set_freq=3000.0, meas_freq=2994.0119628906, set_ampl=2.0, meas_ampl=4.0799999237
# └ @ Main In[6]:27
# ┌ Info: set_freq=3000.0, meas_freq=3003.0029296875, set_ampl=2.5, meas_ampl=5.2000002861
# └ @ Main In[6]:27
# ┌ Info: set_freq=3000.0, meas_freq=3007.5187988281, set_ampl=3.0, meas_ampl=6.0599999428
# └ @ Main In[6]:27
# ┌ Info: set_freq=4000.0, meas_freq=3992.0161132813, set_ampl=0.5, meas_ampl=1.0299999714
# └ @ Main In[6]:27
# ┌ Info: set_freq=4000.0, meas_freq=4016.0642089844, set_ampl=1.0, meas_ampl=2.0399999619
# └ @ Main In[6]:27
# ┌ Info: set_freq=4000.0, meas_freq=4008.0158691406, set_ampl=1.5, meas_ampl=3.0899999142
# └ @ Main In[6]:27
# ┌ Info: set_freq=4000.0, meas_freq=3999.9997558594, set_ampl=2.0, meas_ampl=4.0799999237
# └ @ Main In[6]:27
# ┌ Info: set_freq=4000.0, meas_freq=3999.9997558594, set_ampl=2.5, meas_ampl=5.2000002861
# └ @ Main In[6]:27
# ┌ Info: set_freq=4000.0, meas_freq=4008.0158691406, set_ampl=3.0, meas_ampl=6.0599999428
# └ @ Main In[6]:27

# %% [markdown]
# 4.4.5 Oprirea instrumentelor

# %% [markdown]
# 4.4.6 Generarea caracteristicilor, dupa incheierea masuratorilor

# %%
# frecventa
h1=plot(in_freq, meas_freq; markershape=:circle, label="frecventa setata vs masurata");
title!("Frecventa setata vs masurata");
xlabel!("[Hz]");
ylabel!("[Hz]");
display(h1)

# %%
# amplitudinea
h2=plot(in_amplit, meas_amplit; markershape=:circle, label="amplitudinea setata vs masurata"); # ,ylims=(0, 6)
title!("Amplitudinea setata vs masurata");
xlabel!("[V]");
ylabel!("[V]");
display(h2)

# %% [markdown]
# 4.4.7 Salvarea datelor in fisierul .csv

# %%
df = DataFrame(
    "Frecventa [Hz]" => in_freq,
    "Frecventa masurata [Hz]" => meas_freq,
    "Amplitudinea [V]" => in_amplit,
    "Amplitudinea masurata [V]" => meas_amplit,
    )
CSV.write("0004_caract_semnale.csv", df)
# Out:
# "0004_caract_semnale.csv"

# %% [markdown]
# 4.4.8 Deconectarea instrumentelor

# %%
disconnect!(fgen_handle)
disconnect!(scope_handle)
# Out:
# 0

# %% [markdown]
# #### 4.5 Desfasurarea lucrarii:

# %% [markdown]
# 1. Adăugați în interiorul buclei for o funcție care ajustează offset-ul generatorului de semnal.
# 2. Adăugați o măsurătoare în cadrul osciloscopului pentru offset-ul semnalului.
# 3. Adăugați în fișier două coloane: offset-ul reglat și cel măsurat.
